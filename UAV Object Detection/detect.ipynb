# %% [markdown]
# # Mini-Projekt 2: UAV Object Detection (20 Minuten)
#
# **Ziel:**
#
# Objekte in einem Luftbild erkennen.
#
# Beispiele:
#
# * Autos
#
# * Personen
#
# * Fahrräder
#
# * Busse

# %%
# Bibliothek installieren im Notebook
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.6 MB/s eta 0:00:00
# ...

# %%
# YOLO laden
"""
YOLO = You Only Look Once

Sehr bekannte Methode für:

Object Detection

Robotics

UAV Vision
"""
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
# Zum Testen kann ich einfach ein Bild aus dem Internet speichern, z.B.:
import urllib.request

url = "https://ultralytics.com/images/bus.jpg"
urllib.request.urlretrieve(url, "example.jpg")
# Out:
# ('example.jpg', <http.client.HTTPMessage at 0x7a2b7123db20>)

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("example.jpg")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(809.5), np.float64(1079.5), np.float64(-0.5))

# %% [markdown]
# Ich trainiere nichts selbst (das dauert lange), sondern nutze ein vortrainiertes Modell – das ist für ein erstes Projekt völlig in Ordnung.

# %%
import urllib.request

url = "https://ultralytics.com/images/bus.jpg"
urllib.request.urlretrieve(url, "test.jpg")
# Out:
# ('test.jpg', <http.client.HTTPMessage at 0x7a2b7451fad0>)

# %%
results = model("test.jpg", save=True)
# Out:
# image 1/1 /content/test.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 504.4ms
# Speed: 51.0ms preprocess, 504.4ms inference, 57.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("runs/detect/predict/test.jpg")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(809.5), np.float64(1079.5), np.float64(-0.5))
